# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import datetime
from datetime import date
import smtplib
import ssl

url= 'https://bip.dolnyslask.pl/o,2149,informacje-i-obwieszczenia.html?sort=13_&sort_dir=desc'
PATH= 'C:\Program Files (x86)\chromedriver.exe'
driver =  webdriver.Chrome(PATH)
driver.get(url)
time.sleep(5)
soup= BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8872\4242586756.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver =  webdriver.Chrome(PATH)
# <html data-react-helmet="lang" lang="pl"><head><link href="/manifest.json" rel="manifest"/><link href="/favicon.ico" rel="shortcut icon"/><link href="/favicon.ico" rel="shortcut icon"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="#000000" property="theme-color"/><meta content="Main page" property="description"/><meta content="FEb8Hm5vvfZedl6l3ze9yXKxQLV2UmWAd-EJidUTujY" property="google-site-verification"/><title>Informacje i Obwieszczenia | Urząd Marszałkowski Województwa Dolnośląskiego</title><script async="" id="www-widgetapi-script" src="https://www.youtube.com/s/player/4248d311/www-widgetapi.vflset/www-widgetapi.js" type="text/javascript"></script><script async="" src="https://www.youtube.com/iframe_api" type="text/javascript"></script><link href="/static/css/5.bd3f0b93.chunk.css" rel="stylesheet"/><link href="/static/css/main.e8c00b86.chunk.css" rel="stylesheet"/><style data-styled="active" data-styled-version="5.1.1"></style><meta content="https://bip.dolnyslask.pl/e,deklaracja.html" data-react-helmet="true" data-showdeclaration="true" name="deklaracja-dostępności"/><meta content="Informacje i Obwieszczenia | Urząd Marszałkowski Województwa Dolnośląskiego" data-react-helmet="true" name="description"/></head><body><nav style="visibility:hidden;height:0"><a href="/" id="home" style="pointer-events: auto;">Home</a> | <a id="calc" style="pointer-events: none;">Calculators</a></nav><div class="size-0" id="root"><div class="sc-fzppip gBArqA"><ul style="list-style-type: none; margin-top: 0px; margin-bottom: 0px;"><li><a class="sc-fznAgC bMQsvL" href="#skip-link-aside">Przejdź do nawigacji</a></li><li><a class="sc-fznAgC bMQsvL" href="#skip-link-main">Przejdź do treści</a></li><li><button class="sc-fznAgC bMQsvL">Przejdź do wyszukiwarki</button></li><li><a class="sc-fznAgC bMQsvL" href="https://bip.dolnyslask.pl/e,deklaracja.html">Przejdź do deklaracji dostępności</a></li></ul><div class="sc-fzqyvX eOQcGc"><div class="sc-fzoCUK kBjMiw" id="top-bar"><div class="sc-fzoOEf eXkYNB"><div class="sc-fzqKVi dniAaf"><div class="sc-fzooss ivOodO"><a aria-label="Rss" class="sc-fzqARJ sc-fzqNqU jfnGRq sc-fznBtT ccaska" data-color="secondary" data-contrast="false" href="https://bip.dolnyslask.pl/api/contexts/default/rss" id="rss" target="rss_resource"><span aria-hidden="true" class="fa fa-rss"></span></a><a aria-label="Pomoc" class="sc-fzqARJ sc-fzqNqU jfnGRq sc-fznBtT ccaska" data-color="secondary" data-contrast="false" href="https://bip.dolnyslask.pl/a,14599,pomoc.html" id="help-article" target="_self"><span aria-hidden="true" class="fa fa-question-circle"></span></a><div class="sc-fzobTh ktGuED"><ul class="sc-fzqMdD fZQoNm"><li><button aria-label="Odstęp między akapitami" aria-pressed="false" class="sc-fzoaKM rBCOC" id="paragraph-spacing-button"><span aria-hidden="true" class="fa fa-arrows-v"></span> <span class="fa fa-paragraph"></span></button></li><li><button aria-label="Odstęp między wierszami" aria-pressed="false" class="sc-fzoaKM rBCOC" id="line-spacing-button"><span aria-hidden="true" class="fa fa-arrows-v"></span> <span aria-hidden="true" class="fa fa-align-left"></span></button></li><li><button aria-label="Odstęp między słowami" aria-pressed="false" class="sc-fzoaKM rBCOC" id="word-spacing-button"><span aria-hidden="true" class="fa fa-arrows-h"></span> <span aria-hidden="true" class="fa fa-align-left"></span></button></li><li><button aria-label="Odstęp między literami" aria-pressed="false" class="sc-fzoaKM rBCOC" id="letter-spacing-button"><span aria-hidden="true" class="fa fa-arrows-h"></span> A</button></li><li><div><button accesskey="J" aria-label="Normalna wielkość liter" aria-pressed="true" class="sc-fzoaKM rBCOC" id="normal-letters-button">A</button></div></li><li><button aria-label="Duża wielkość liter" aria-pressed="false" class="sc-fzoaKM rBCOC" id="medium-letters-button">A+</button></li><li><button aria-label="Bardzo duża wielkość liter" aria-pressed="false" class="sc-fzoaKM rBCOC" ...

# %%
date_bip= soup.find('td', {'class': 'sc-pAkoP iqlssu'})
today_date= date.today()
today_date= date.fromisoformat(str(today_date))
d= date.fromisoformat(date_bip.text)

# %%
def send_email():   
    smtp_server= 'smtp.gmail.com'
    smtp_port= 587
    email_from= 'testowymailmmmb7943@gmail.com'
    email_to= 'magda.bigaj@wp.pl'
    pswd= 'jannivkjemramsfn'

    message= 'There are some BIP changes'
    simple_email_context = ssl.create_default_context()

    try:
        TIE_server= smtplib.SMTP(smtp_server, smtp_port)
        TIE_server.starttls(context= simple_email_context)
        TIE_server.login(email_from, pswd)
        print('Connecting to server...')
        print(f'Sending email to {email_to}')
        TIE_server.sendmail(email_from, email_to, message)
        print(f'Email succesfully sent to {email_to}')


    except Exception as e:
        print(e)
    finally:
        TIE_server.close()


if d== today_date:
    send_email()
else:
    print("no changes")
# Out:
# no changes

# %%
# import requests
# import re
# from bs4 import BeautifulSoup
# import pandas as pd
# import smtplib
# from datetime import date
# import json
# import html5lib
# import urllib

#jann ivkj emra msfn
